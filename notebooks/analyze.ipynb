# %%
import numpy as np
import prettypyplot as pplt
from matplotlib import pyplot as plt

from pytrale import Trale

pplt.use_style(figsize=(8, 2), latex=False)

# %%
db = Trale.fromFile('../../trale/python/trale_2024-01-29.txt')

# %%
fig, ax = plt.subplots()

ax.scatter(db.times_measured, db.weights_measured)
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(db.times, db.weights_linear_interpol, alpha=0.5)
ax.scatter(db.times_measured, db.weights_measured)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 fig, ax = plt.subplots()
# ----> 3 weights_interpol = db.interpolate(weights)
#       5 ax.plot(db.times, db.weights_linear_interpol, alpha=0.5)
#       6 ax.scatter(db.times_measured, db.weights_measured)
#
# AttributeError: 'Trale' object has no attribute 'interpolate'
